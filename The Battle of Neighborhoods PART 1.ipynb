# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# ### I decided to analyze the similatiries between the cities of New York and Toronto. The main goal is to compare the neighborhoods to know what aspects make people from other countries come and live there. The other thing is to determine the fundamental aspects that make both of them two of the most touristic cities in the United States and Canada.

# %% [markdown]
# # Data explanation

# %% [markdown]
# ### The data I'm going to be using is from the previous exercises about New York City and Toronto Canada. I'm going to use the foursquare API to extract some additional information.
#
# ### I'm going to compare the amount of stores in both areas and venues around the neighborhoods. I'll also show pandas Data Frames with the main aspects and folium maps to visualyze them.
