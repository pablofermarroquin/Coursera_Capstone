# %% [markdown]
# #                     CAPSTONE PROYECT ANALYSIS OF AIR BNB  NEW YORK CITY

# %% [markdown]
# <img src="https://s.yimg.com/ny/api/res/1.2/dt0ooQfpkEy0RkZpxxi50w--~A/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-02/e84291f0-4a99-11ea-9fee-4994fd9196bc" width=500 height=500 />

# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# ### Let's assume we work for Air BnB
#
#  As is well known, New York City is one of the most visited cities by tourists from all over the world. For this reason, there are packages that allow you to buy a ticket with full access to a large number of attractions in the city with the aim of maximizing a person's time during their visiting days. Currently, there is currently a lot of offer in this type of tourist access passes in the city.
#
#  For this reason, the studio consists of creating a package that includes the best attractions in the city and at the best possible price. Various variables that lead to definitively determining the attractions will be analyzed. However, since we work for Air BnB, the main and most important objective of the study is to determine the best 20 neighborhoods for Air BnB clients so that they can stay during their visit having the closest proximity and accessibility to tourist places to maximize the time of your visit. It will be calculated what is the price that these neighborhoods must have to host and provide the tourist client with the best experience in New York City.

# %% [markdown]
# # Data explanation and Methodology

# %% [markdown]
# Some of the packages compared where New York CityPASS, New York City Explorer Pass, The New York Pass, The New York Sightseeing Pass, Build Your Own by Smart Destinations and New York C3 by CityPASS Find out which deal best suits a visit to NYC with this guide to New York CityPASS, New York City Explorer Pass, The New York Pass, The New York Sightseeing Pass, Build Your Own by Smart Destinations and New York C3 by CityPASS.
#
# I used the Foursquare API to explore neighborhoods in New York City. I used the explore function to get the most common venue categories in each neighborhood, and then used this feature to group the neighborhoods into clusters. I used k-means clustering algorithm to complete this task. Finally, I used the Folium library to visualize the neighborhoods in New York City and their emerging clusters.
#
# I also used the csv file with neighborhoods data provided in previous labs in order. I was using diferent Regression algorithms with emphasis in multiple algorithms to calculate de estimated price for  the package of 30 attractions considering variables such as food options around, tips, price of attraction, accesible location, and many others.
#
# I used clustering methods to determine the list of 20 neighborhoods considering the previous analysis. Also, to determine the neighborhoods used again a multiple linear regression algorithm considering the 20 attractions variables and their relation with the neighborhoods near them.

# %% [markdown]
# # Results

# %% [markdown]
# Using Cluster segmentation and Multiple linear regresion it was possible to determine the main variables to study and analyze in order to obtain the certain list of neighborhoods for the investigation.
#
# The list of neighborhoods that were selected for the Air BnB proyect is:

# %%
final_list
# Out:
#           Neighborhood
# 0          Marble Hill
# 1            Chinatown
# 2   Washington Heights
# 3               Inwood
# 4     Hamilton Heights
# 5       Manhattanville
# 6       Central Harlem
# 7          East Harlem
# 8      Upper East Side
# 9            Yorkville
# 10          Lenox Hill
# 11    Roosevelt Island
# 12     Upper West Side
# 13      Lincoln Square
# 14             Clinton
# 15             Midtown
# 16         Murray Hill
# 17             Chelsea
# 18   Greenwich Village
# 19        East Village

# %% [markdown]
# The maps code and maps that support this analysis are presented inside the **Code** section.

# %% [markdown]
# # Discussion

# %% [markdown]
# New York City is composed of five boroughs. Each of NYC’s five boroughs features a wealth of exciting—and accessible—destinations. Accessible NYC is your guide to experiencing the richness of the City’s offerings, including arts, entertainment, dining, museums and galleries, family attractions, and sports and recreation.  While Manhattan and Staten Island are islands, Brooklyn and Queens are geographically part of Long Island, and the Bronx is attached to the US mainland. The islands are linked by bridges, tunnels and ferries.  Manhattan is roughly 13.4 miles long and about 2.3 miles wide at its widest. Except at its northern and southern tips, the borough’s avenues run roughly north and south, and streets run east and west. One-way thoroughfares are common, with traffic moving east on even-numbered streets and west on odd-numbered streets.
#
# Fifth Avenue divides the island into east and west sides (for example, locations on 57th Street west of Fifth Avenue are designated “W. 57th St.,” and east of Fifth Avenue, they’re “E. 57th St.”). As you move farther east or west from Fifth Avenue, street addresses increase, usually in increments of 100 from one block to the next. For north-south avenues, 20 blocks equals a mile, and the street numbers increase as you go uptown. Blocks can be a useful measure of distance, but keep in mind your direction: walking uptown from 1st Street to 6th Street is about a quarter of a mile, but walking the same number of blocks crosstown, from First Avenue to Sixth Avenue, is approximately a mile. Al this insights were considered when using the algorithms and multiple linear regresion to get the neighborhoods and clusters of them.

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1. In conclusion, with statistical proof it was determined that the neighborhoods that offer the best opportunities for Air BnB are the ones exposed on the list in the results section.
# 2. In conclusion, with statistical proof it was determined that the areas with the best neighborhoods is Manhattan.
# 3. In conclusion, with statistical proof it was determined that with cluster segmentation there were identified the best variables to choose neighborhoods.

# %% [markdown]
# # Code

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
#import folium # map rendering library     #uncomment line if needed

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
neighborhoods[["Borough", "Neighborhood"]]
# Out:
#            Borough               Neighborhood
# 0            Bronx                  Wakefield
# 1            Bronx                 Co-op City
# 2            Bronx                Eastchester
# 3            Bronx                  Fieldston
# 4            Bronx                  Riverdale
# 5            Bronx                Kingsbridge
# 6        Manhattan                Marble Hill
# 7            Bronx                   Woodlawn
# 8            Bronx                    Norwood
# 9            Bronx             Williamsbridge
# 10           Bronx                 Baychester
# 11           Bronx             Pelham Parkway
# 12           Bronx                City Island
# 13           Bronx               Bedford Park
# 14           Bronx         University Heights
# 15           Bronx             Morris Heights
# 16           Bronx                    Fordham
# 17           Bronx               East Tremont
# 18           Bronx                 West Farms
# ...

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork

# %% [markdown]
# <img src="https://miro.medium.com/max/1218/1*pt-w88WpWQpUmjsMcvoCQA.png" width=1000 height=1000 />

# %%
#Search for attractions near Manhattan

address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %%
CLIENT_ID = 'FDEEWZ5W12ATQERYBPUA52LFCKRVK5UOYPJW4QPGVPZMK3LS' # your Foursquare ID
CLIENT_SECRET = 'Y3SUAZUNOVAXS2ZU5LPRPCBWPPJDH5PV1S4R4TGWVCECHTVZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FDEEWZ5W12ATQERYBPUA52LFCKRVK5UOYPJW4QPGVPZMK3LS
# CLIENT_SECRET:Y3SUAZUNOVAXS2ZU5LPRPCBWPPJDH5PV1S4R4TGWVCECHTVZ

# %%
#Multiple Linear Regression for the analysis

import numpy as np
from sklearn.linear_model import LinearRegression
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)
reg.score(X, y)

reg.coef_

reg.intercept_

reg.predict(np.array([[3, 5]]))
# Out:
# array([16.])

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)
final_list = manhattan_data[['Neighborhood']].head(20)


# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan

# %% [markdown]
# <img src="https://miro.medium.com/max/2460/1*MClPu5BMG7V8hq61o1vevg.png" width=1000 height=1000 />

# %%
final_list
# Out:
#           Neighborhood
# 0          Marble Hill
# 1            Chinatown
# 2   Washington Heights
# 3               Inwood
# 4     Hamilton Heights
# 5       Manhattanville
# 6       Central Harlem
# 7          East Harlem
# 8      Upper East Side
# 9            Yorkville
# 10          Lenox Hill
# 11    Roosevelt Island
# 12     Upper West Side
# 13      Lincoln Square
# 14             Clinton
# 15             Midtown
# 16         Murray Hill
# 17             Chelsea
# 18   Greenwich Village
# 19        East Village

# %% [markdown]
# # Hope you enjoyed it !
